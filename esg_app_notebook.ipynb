# %%
import numpy as np
from collections import defaultdict
import pandas as pd
from scipy import stats
import urllib
import urllib.parse
import pathlib
import os

# %% [markdown]
# ## Dataframe is 323 rows by 63 columns with missing values present throughout
# - Data should be loaded into JSON format to extract hierarchical relationships

# %%
'''--------------------- Part One: Dataframe construction -----------------------'''
df0 = pd.read_csv(r"C:\Users\David\Documents\MacBook Backup\Python files\RGMP\summer 2019\my_dash_app\myenv\env_with_financial-1.csv",header=None)
df1 = df0.replace(np.NaN,'')
df = np.array(df1)
df1
# Out:
#           0                                         1   \
# 0
# 1
# 2
# 3     Ticker                                      Name
# 4     GRO CN                    GrowMax Resources Corp
# ..       ...                                       ...
# 318   D-U CN  Dream Office Real Estate Investment Trus
# 319   CPX CN                        Capital Power Corp
# 320   CHR CN                       Chorus Aviation Inc
# 321    CR CN                           Crew Energy Inc
# 322  SMTX US                                 SMTC Corp
#
#                                2              3                           4   \
# 0                         Damages
# 1                  Damages Bucket
# 2    Environmental Fines (Amount)                  Total Discharges to water
# 3      Average annual change [5y]  % Change [5y]  Average annual change [5y]
# 4
# ..                            ...            ...                         ...
# 318
# 319                                                                 -4790400
# 320
# 321
# 322
#
#                 5                           6              7   \
# 0
# 1
# 2                    Amount of Spills (Tonnes)
# 3    % Change [5y]  Average annual change [5y]  % Change [5y]
# 4
# ..             ...                         ...            ...
# 318
# 319   -0.123936666
# 320
# 321
# 322
#
#                              8              9   ...          54  \
# 0                                               ...
# 1                                               ...
# 2      Hazardous Waste (Tonnes)                 ...
# 3    Average annual change [5y]  % Change [5y]  ...  2017 Value
# 4                                               ...
# ..                          ...            ...  ...         ...
# 318                                             ...       19.35
# 319                           0                 ...       19.26
# 320                                             ...        6.82
# 321                                             ...       66.87
# 322                                             ...
#
#                              55          56                 57  \
# 0
# 1                                            Volatility Bucket
# 2          Debt to Equity Ratio                  Adjusted Beta
# 3    Average annual change [5y]  2017 Value         2017 Value
# 4                             -           -               0.87
# ..                          ...         ...                ...
# 318                        -1.1        78.8               0.29
# 319                        2.07       70.64                1.8
# 320                       24.57       397.7              -0.12
# 321                        3.16        36.3               8.67
# 322                       11.87      107.24               2.01
#
#                              58          59                          60  \
# 0
# 1     Company Valutation Bucket
# 2                    Market Cap                                      EV
# 3    Average annual change [5y]  2017 Value  Average annual change [5y]
# 4                  -12729249.42    21036300                -63926097.11
# ..                          ...         ...                         ...
# 318                 -8788637.22  1711293200                -704381876.9
# 319                 10851010.88  2575808300                 193344876.7
# 320                 27662696.58  1286581700                 300580466.1
# 321                -17263564.85   469210900                -103582622.7
# 322                 46922609.19    31809700                  -1172634.1
#
#              61                      62          63
# 0
# 1                    Descriptive Bucket
# 2                              Industry     Country
# 3    2017 Value              2017 Value  2017 Value
# 4     -12449700               Materials          CA
# ..          ...                     ...         ...
# 318  2981983200             Real Estate          CA
# 319  5493808300               Utilities          CA
# 320  2330184700             Industrials          CA
# 321   785049900                  Energy          CA
# 322    46727700  Information Technology          CA
#
# [323 rows x 64 columns]

# %%
# We can see that there are 4 rows comprising headings for the hierarchical dataset
# This function will extract each level of heading for a given datapoint and add it to a dictionary
# x is the index value  for each non-empty value in the dataset
def get_dict_keys(x, df):
    return [[k.strip() for idx, k in enumerate(df[i]) if k != '' and idx <= x][-1] for i in range(4)]

def get_json():

    # create dict of company data
    nested_dict = lambda: defaultdict(nested_dict)
    data = nested_dict()

    for idx_row, row in enumerate(df):
        for idx_val, value in enumerate(row):
            # passing first four headers and first two columns
            if idx_row < 4 or idx_val < 2:
                continue

            # if data exists
            if value != '' and value != '--' and value != '-':

                # ticker
                tick = df[:, 0][idx_row]

                # find keys and add value
                keys_fin = get_dict_keys(idx_val, df)
                data[tick][keys_fin[0]][keys_fin[1]][keys_fin[2]][keys_fin[3]] = value

    return dict(data)

# %%
# get all keys at every depth
def key_at_depth(dct, dpt):
     if dpt > 0:
         return [key for k, subdct in dct.items() for key in key_at_depth(subdct, dpt-1)]
     else:
         return dct.keys()

# Retrieve data array given a set of keys
def get_data_arr(data, key1, key2, key3, key4):
    tickers, data_points = [], []
    for t, _ in data.items():
        try:
            data_points.append(float(data[t][key1][key2][key3][key4]))
            tickers.append(t)
        except:
            pass

    return tickers, data_points


data = get_json()

# %% [markdown]
# ## Initialize Arrays

# %%
# get all keys at every depth
keys_fin = [list(set(key_at_depth(data, i))) for i in range(5)]
keys_fin = [sorted(set(x)) for x in keys_fin]

#creating bubble plot dropdown menu options
'''damages topic'''
damages_q = keys_fin[1][0]
dmgs_bckts_list = [damages_q]

damages_bucket_q = keys_fin[2][1]
env_fines_amt_q = keys_fin[3][9]
discharges_water_q = keys_fin[3][19]
amt_spills_q = keys_fin[3][2]
hazardous_waste_q = keys_fin[3][12]
dmgs_bckt_list = [env_fines_amt_q, discharges_water_q, amt_spills_q, hazardous_waste_q]

'''emissions topic'''
emissions_q = keys_fin[1][1]

total_emissions_bucket_q = keys_fin[2][8]
direct_co2_emissions_q = keys_fin[3][5]
ghg_emissions_q = keys_fin[3][22]
ods_emissions_q = keys_fin[3][15]
tot_emns_bckt_list = [direct_co2_emissions_q, ghg_emissions_q, ods_emissions_q]

emissions_per_sales_energy_q = keys_fin[2][3]
ghg_intensity_energy_q = keys_fin[3][11]
ghg_intensity_sales_q = keys_fin[3][10]
emns_sales_eng_list = [ghg_intensity_energy_q, ghg_intensity_sales_q]

emns_bckts_list = [total_emissions_bucket_q, emissions_per_sales_energy_q]

'''recycled resources topic'''
recycled_resources_q = keys_fin[1][3]

water_recycled_bucket_q = keys_fin[2][13]
pct_water_recycled_q = keys_fin[3][0]
tot_water_recycled_q = keys_fin[3][25]
wat_recy_bckt_list = [pct_water_recycled_q, tot_water_recycled_q]

energy_recycled_bucket_q = keys_fin[2][5]
renewables_pct_energy_q = keys_fin[3][23]
renewable_energy_use_q = keys_fin[3][17]
eng_recy_bckt_list = [renewables_pct_energy_q,renewable_energy_use_q]

waste_recycled_bucket_q = keys_fin[2][11]
waste_recycled_pct_total_q = keys_fin[3][28]
waste_recycled_q = keys_fin[3][27]
waste_recy_bckt_list = [waste_recycled_pct_total_q, waste_recycled_q]

recy_res_bckts_list = [water_recycled_bucket_q,energy_recycled_bucket_q,waste_recycled_bucket_q]

'''resource consumption topic'''
resource_consumption_q = keys_fin[1][4]

water_consumption_bucket_q = keys_fin[2][12]
water_use_q = keys_fin[3][26]
water_intensity_sales_q = keys_fin[3][29]
wat_cons_bckt_list = [water_use_q, water_intensity_sales_q]

energy_consumption_bucket_q = keys_fin[2][4]
energy_consumption_q = keys_fin[3][20]
energy_intensity_sales_q = keys_fin[3][8]
eng_cons_bckt_list = [energy_consumption_q, energy_intensity_sales_q]

waste_consumption_bucket_q = keys_fin[2][10]
tot_waste_q = keys_fin[3][24]
waste_generated_sales_q = keys_fin[3][30]
wast_cons_bckt_list = [tot_waste_q, waste_generated_sales_q]

rsc_cons_bckts_list = [water_consumption_bucket_q, energy_consumption_bucket_q, waste_consumption_bucket_q]

'''Financials topic'''
financials_topic_q = keys_fin[1][2]

gaap_bucket_q = keys_fin[2][6]
revenue_q = keys_fin[3][18]
eps_q = keys_fin[3][6]
gaap_bckt_list = [revenue_q, eps_q]

ratios_bucket_q = keys_fin[2][7]
pe_ratio_q = keys_fin[3][16]
debt_to_equity_q = keys_fin[3][4]
ratios_bckt_list = [pe_ratio_q, debt_to_equity_q]

volatility_bucket_q = keys_fin[2][9]
adjusted_beta_q = keys_fin[3][1]
vol_bckt_list = [adjusted_beta_q]

company_valuation_bucket_q = keys_fin[2][0]
market_cap_q = keys_fin[3][14]
ev_q = keys_fin[3][7]
comp_val_bckt_list = [market_cap_q, ev_q]

descriptive_bucket_q = keys_fin[2][2]
industry_q = keys_fin[3][13]
country_q = keys_fin[3][3]
desc_bckt_list = [industry_q, country_q]

finc_bckts_list = [gaap_bucket_q, ratios_bucket_q, volatility_bucket_q,\
                   company_valuation_bucket_q, descriptive_bucket_q ]
'''calculations'''
pct_change_q = keys_fin[4][0]
value_2017_q = keys_fin[4][1]
value_change_q = keys_fin[4][2]
prop_change_q = keys_fin[4][3]

topics_list = [damages_q, emissions_q, recycled_resources_q, resource_consumption_q]

buckets_list = [damages_bucket_q, total_emissions_bucket_q, emissions_per_sales_energy_q,\
                water_recycled_bucket_q, energy_recycled_bucket_q, waste_recycled_bucket_q,\
                water_consumption_bucket_q, energy_consumption_bucket_q, waste_consumption_bucket_q]

metrics_list = [env_fines_amt_q, discharges_water_q, amt_spills_q, hazardous_waste_q,\
                direct_co2_emissions_q, ghg_emissions_q, ods_emissions_q,\
                ghg_intensity_energy_q, ghg_intensity_sales_q, pct_water_recycled_q,\
                tot_water_recycled_q, renewables_pct_energy_q,renewable_energy_use_q,\
                waste_recycled_pct_total_q, waste_recycled_q,water_use_q,water_intensity_sales_q,\
                energy_consumption_q, energy_intensity_sales_q,tot_waste_q, waste_generated_sales_q]

size_parameters_list = [market_cap_q,revenue_q]

calculations_list = [pct_change_q, value_2017_q, value_change_q, prop_change_q]


lst = [env_fines_amt_q, discharges_water_q, amt_spills_q, hazardous_waste_q]
base_key1 = keys_fin[1][3]
base_key2 = keys_fin[2][5]
base_key3 = keys_fin[3][17]
base_key4 = keys_fin[4][0]
base_x,base_y = get_data_arr(data, base_key1, base_key2, base_key3, base_key4)

# %%
data
# Out:
# {'GRO CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-9241574.6'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.01',
#                                                      '2017 Value': '-0.02'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.87'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-12729249.42',
#                                                      '2017 Value': '21036300'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-63926097.11',
#                                                      '2017 Value': '-12449700'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Materials'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'S CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Water Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'% Water Recycled': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '14.054'})}),
#                            'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})}),
#               'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-41600000',
#                                                      '2017 Value': '267300000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.18',
#                                                      '2017 Value': '0.99'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '4.41',
#                                                      '2017 Value': '78.02'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '3.4'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-17550114.38',
#                                                      '2017 Value': '515521200'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-407505980.2',
#                                                      '2017 Value': '1136621200'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Materials'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})})}),
#  'H CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '52400000',
#                                                      '2017 Value': '5990000000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.02',
#                                                      '2017 Value': '1.11'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.43',
#                                                      '2017 Value': '20.36'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-2.56',
#                                                      '2017 Value': '111.97'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.96'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '1277520.99',
#                                                      '2017 Value': '13336659800'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '25281659800'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Utilities'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'BTO CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Water Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'% Water Recycled': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '55'})}),
#                            'Waste Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Waste recycled % total waste (make)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '3.28E-05'})}),
#                            'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})}),
#               'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '75925200',
#                                                      '2017 Value': '638677000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.01',
#                                                      '2017 Value': '0.06'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '7.1',
#                                                      '2017 Value': '52.76'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '8.82',
#                                                      '2017 Value': '44.83'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '6.53'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '36245745.05',
#                                                      '2017 Value': '3802746600'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '284641560.1',
#                                                      '2017 Value': '4515535400'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Materials'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})})}),
#  'CUF-U CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '54190400',
#                                                      '2017 Value': '835489000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-1.05',
#                                                      '2017 Value': '-2.13'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.41',
#                                                      '2017 Value': '10.57'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '7.11',
#                                                      '2017 Value': '139.99'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.46'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-4712922.26',
#                                                      '2017 Value': '2667361100'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '261107774.5',
#                                                      '2017 Value': '7152502100'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Real Estate'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'CHP-U CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '830630000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.98'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '22.52'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '458.71'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '1.21'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '28925850.82',
#                                                      '2017 Value': '5386590000'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '9686914000'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Real Estate'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'ARX CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Damages': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Damages Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Environmental Fines (Amount)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0'}),
#                                         'Amount of Spills (Tonnes)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '5.707198381',
#                                                      '% Change [5y]': '0.011495254'})})}),
#               'Emissions': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Total Emissions Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total GHG Emissions (Tonnes)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '2517.199707',
#                                                      '% Change [5y]': '0.002520062'})}),
#                            'Emissions per sales/energy consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total GHG CO2 Emissions Intensity per Sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-17.01035613',
#                                                      '% Change [5y]': '-0.020328355'}),
#                                         'Greenhouse gas intensity per energy consumption': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-10.86861111',
#                                                      '% Change [5y]': '-0.028295205'}),
#                                         'Greenhouse Gas Intensity per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-17.01035613',
#                                                      '% Change [5y]': '-0.020328355'})})}),
#               'Resource Consumption': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Water Consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total Water Use': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '289079.1992',
#                                                      '% Change [5y]': '0.306197477'}),
#                                         'Water intensity per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '197.0030175',
#                                                      '% Change [5y]': '0.249088018'})}),
#                            'Energy Consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total Energy Consumption (MwH)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '93338.03711',
#                                                      '% Change [5y]': '0.03589331'}),
#                                         'Energy intensity per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '20.2154848',
#                                                      '% Change [5y]': '0.009279706'})})}),
#               'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '30360000',
#                                                      '2017 Value': '1345500000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.13',
#                                                      '2017 Value': '1.1'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.52',
#                                                      '2017 Value': '30.26'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.33',
#                                                      '2017 Value': '24.84'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '4.66'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-14481724.58',
#                                                      '2017 Value': '5217854700'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-577674265.2',
#                                                      '2017 Value': '5908954700'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Energy'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'TSGI CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '247165196',
#                                                      '2017 Value': '1312315000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.38',
#                                                      '2017 Value': '1.77'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '18.03'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '2.81',
#                                                      '2017 Value': '102.39'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '-2.27'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '12599617.2',
#                                                      '2017 Value': '4320278800'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '1284709943',
#                                                      '2017 Value': '7777432700'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Consumer Discretionary'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'PDL CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '22339200',
#                                                      '2017 Value': '272400000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '31.3',
#                                                      '2017 Value': '0.62'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '11.67'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-6.56',
#                                                      '2017 Value': '20.01'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.15'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '260015861.3',
#                                                      '2017 Value': '427230000'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '62473984.17',
#                                                      '2017 Value': '501730000'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Materials'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'SGY CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '11872400',
#                                                      '2017 Value': '216908000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.14',
#                                                      '2017 Value': '-0.03'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '3.37',
#                                                      '2017 Value': '40.56'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-4.71',
#                                                      '2017 Value': '31.89'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '5.78'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-11158095.83',
#                                                      '2017 Value': '486803800'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '46167280.94',
#                                                      '2017 Value': '734340800'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Energy'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'DRG-U CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '25013400',
#                                                      '2017 Value': '263728000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.35',
#                                                      '2017 Value': '1.92'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-1.88',
#                                                      '2017 Value': '17.09'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-4.58',
#                                                      '2017 Value': '99.02'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '-0.84'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '39178035.24',
#                                                      '2017 Value': '2149769200'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '584606674.5',
#                                                      '2017 Value': '4221118200'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Real Estate'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'GUD CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '8634000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '0.12'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '101.41'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '3.92'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '14373948.09',
#                                                      '2017 Value': '1186719000'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '421686000'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Health Care'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'ALA CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '238215400',
#                                                      '2017 Value': '2618700000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.18',
#                                                      '2017 Value': '0.18'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '2.78',
#                                                      '2017 Value': '46.92'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-11.19',
#                                                      '2017 Value': '79.16'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '1.8'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-896835.45',
# ...
#                                                     {'Average annual change [5y]': '-6200',
#                                                      '% Change [5y]': '-0.026839827'})})}),
#               'Resource Consumption': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Water Consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total Water Use': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-5915200',
#                                                      '% Change [5y]': '-0.101503192'}),
#                                         'Water intensity per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-3505.638175',
#                                                      '% Change [5y]': '-0.07796189'})}),
#                            'Energy Consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total Energy Consumption (MwH)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-1181100',
#                                                      '% Change [5y]': '-0.029015663'}),
#                                         'Energy intensity per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '372.2104771',
#                                                      '% Change [5y]': '0.011850575'})}),
#                            'Waste Consumption Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Total Waste (Tonnes)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-23800',
#                                                      '% Change [5y]': '-0.019412724'}),
#                                         'waste generated per sales': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '22.46594906',
#                                                      '% Change [5y]': '0.02374867'})})}),
#               'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-50000000',
#                                                      '2017 Value': '1046000000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.05',
#                                                      '2017 Value': '1.07'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.69',
#                                                      '2017 Value': '19.26'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '2.07',
#                                                      '2017 Value': '70.64'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '1.8'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '10851010.88',
#                                                      '2017 Value': '2575808300'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '193344876.7',
#                                                      '2017 Value': '5493808300'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Utilities'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})})}),
#  'CHR CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-71697200',
#                                                      '2017 Value': '1352200000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.11',
#                                                      '2017 Value': '1.36'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.95',
#                                                      '2017 Value': '6.82'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '24.57',
#                                                      '2017 Value': '397.7'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '-0.12'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '27662696.58',
#                                                      '2017 Value': '1286581700'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '300580466.1',
#                                                      '2017 Value': '2330184700'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Industrials'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'CR CN': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-27339200',
#                                                      '2017 Value': '214001000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '0.01',
#                                                      '2017 Value': '0.23'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'P/E Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '66.87'}),
#                                         'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '3.16',
#                                                      '2017 Value': '36.3'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '8.67'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-17263564.85',
#                                                      '2017 Value': '469210900'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-103582622.7',
#                                                      '2017 Value': '785049900'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Energy'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})}),
#  'SMTX US': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#              {'Financials': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'GAAP Highlights Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Revenue': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-31414800',
#                                                      '2017 Value': '139231000'}),
#                                         'EPS': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-0.19',
#                                                      '2017 Value': '-0.47'})}),
#                            'Ratios Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Debt to Equity Ratio': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '11.87',
#                                                      '2017 Value': '107.24'})}),
#                            'Volatility Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Adjusted Beta': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': '2.01'})}),
#                            'Company Valutation Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Market Cap': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '46922609.19',
#                                                      '2017 Value': '31809700'}),
#                                         'EV': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'Average annual change [5y]': '-1172634.1',
#                                                      '2017 Value': '46727700'})}),
#                            'Descriptive Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Industry': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'Information Technology'}),
#                                         'Country': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'2017 Value': 'CA'})})}),
#               'Recycled Resources': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                           {'Energy Recycled Bucket': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                        {'Renewable Energy Use (Mwh)': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                     {'% Change [5y]': defaultdict(<function __main__.get_json.<locals>.<lambda>()>,
#                                                                  {})})})})})}

# %% [markdown]
# # Breakdown of Categories
#
# ## Emissions
# emns_bckts_list  = [total_emissions_bucket_q, emissions_per_sales_energy_q]
#
# - tot_emns_bckt_list = [direct_co2_emissions_q, ghg_emissions_q, ods_emissions_q]
# - emns_sales_eng_list = [ghg_intensity_energy_q, ghg_intensity_sales_q]
#
# ## Damages
# Damages = 'Damages Bucket'
#
# - dmgs_bckt_list = [env_fines_amt_q, discharges_water_q, amt_spills_q, hazardous_waste_q]
#
# ## Recycled Resources
# recy_res_bckts_list = [water_recycled_bucket_q,energy_recycled_bucket_q,waste_recycled_bucket_q]
#
# - wat_recy_bckt_list = [pct_water_recycled_q, tot_water_recycled_q]
# - eng_recy_bckt_list = [renewables_pct_energy_q,renewable_energy_use_q]
# - waste_recy_bckt_list = [waste_recycled_pct_total_q, waste_recycled_q]
#
#
# ## Resource Consumption
# rsc_cons_bckts_list = [water_consumption_bucket_q, energy_consumption_bucket_q, waste_consumption_bucket_q]
#
# - wat_cons_bckt_list = [water_use_q, water_intensity_sales_q]
# - eng_cons_bckt_list = [energy_consumption_q, energy_intensity_sales_q]
# - wast_cons_bckt_list = [tot_waste_q, waste_generated_sales_q]
#
#
# ## Financials
# finc_bckts_list = [gaap_bucket_q, ratios_bucket_q, volatility_bucket_q,company_valuation_bucket_q, descriptive_bucket_q ]
#
# - gaap_bckt_list = [revenue_q, eps_q]
# - ratios_bckt_list = [pe_ratio_q, debt_to_equity_q]
# - vol_bckt_list = [adjusted_beta_q]
# - comp_val_bckt_list = [market_cap_q, ev_q]
# - desc_bckt_list = [industry_q, country_q]
